# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# df = pd.read_csv("hf://datasets/criteo/FairJob/fairjob.csv.gz")abs
# df.to_csv("fairjob.csv", index=False)

df=pd.read_csv('D:/Harsh/MTech/ML/fairjob.csv/criteo_fairness_dataset_2024-01-01_2024-05-20.csv');

# %%
df
# Out:
#          click  protected_attribute  senior  displayrandom  rank  user_id
# 0            0                    0       1              1     1    31020  \
# 1            0                    0       1              0     3      515
# 2            0                    1       1              0     1    12859
# 3            0                    1       1              0     1    18781
# 4            0                    0       1              0     9    19283
# ...        ...                  ...     ...            ...   ...      ...
# 1072221      0                    0       1              0     5    18385
# 1072222      0                    1       1              0    15    14116
# 1072223      0                    1       0              0    12    16797
# 1072224      0                    0       0              0     2    29846
# 1072225      0                    1       0              0     1    22965
#
#          impression_id  product_id  cat0  cat1  ...     num41     num42
# 0               175316       45953     6     6  ... -0.333033 -0.542801  \
# 1               129699       10569     8     8  ... -0.333033 -0.542801
# 2               134573       51550     6     6  ... -0.333033 -0.542801
# 3                84169       17843     3     3  ... -0.333033 -0.542801
# 4                76506       11354     8     8  ... -0.333033 -0.542801
# ...                ...         ...   ...   ...  ...       ...       ...
# 1072221         103422        6956     5     5  ... -0.333033 -0.542801
# 1072222          92627       38418     6     6  ... -0.333033 -0.542801
# 1072223         108126       60106     7     7  ... -0.050435  0.925347
# 1072224         208934       14518     6     7  ... -0.333033 -0.542801
# 1072225         225012        5486     6     6  ...  0.232163  0.925347
#
#             num43     num44     num45     num46     num47     num48     num49
# 0        0.074884 -0.751637 -0.299223 -0.647541 -0.252768 -0.577173 -0.264359  \
# 1       -0.258659  0.503731 -0.523668  1.088225  0.935563 -0.577173  0.507790
# 2       -0.236209 -0.111510  0.084159  0.422154 -0.160055 -0.577173 -0.264359
# 3       -0.393358 -0.987701 -0.523668 -0.778977 -0.345480 -0.577173  4.368537
# 4        1.553377 -0.636441 -0.523668 -0.541088 -0.345480 -0.577173 -0.264359
# ...           ...       ...       ...       ...       ...       ...       ...
# 1072221 -0.393358 -0.661945 -0.494652 -0.668669 -0.345480 -0.577173 -0.264359
# 1072222  0.113370  1.352636  2.211655  1.445355 -0.160055  0.257664 -0.264359
# 1072223 -0.393358 -0.887341 -0.494652 -0.744993 -0.345480  1.092501 -0.264359
# 1072224 -0.393358 -0.937521 -0.523668 -0.761985 -0.345480 -0.577173 -0.264359
# 1072225 -0.393358 -0.536081 -0.523668 -0.626049 -0.345480  0.257664 -0.264359
#
#             num50
# 0       -0.737299
# 1        0.610287
# 2       -0.063506
# 3       -0.996450
# 4       -0.581808
# ...           ...
# 1072221 -0.633638
# 1072222  1.439571
# 1072223 -0.840959
# 1072224 -0.892789
# 1072225 -0.478148
#
# [1072226 rows x 56 columns]

# %% [markdown]
# ### Basic Details

# %%
df.shape
# Out:
# (1072226, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072226 entries, 0 to 1072225
# Data columns (total 56 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   click                1072226 non-null  int64
#  1   protected_attribute  1072226 non-null  int64
#  2   senior               1072226 non-null  int64
#  3   displayrandom        1072226 non-null  int64
#  4   rank                 1072226 non-null  int64
#  5   user_id              1072226 non-null  int64
#  6   impression_id        1072226 non-null  int64
#  7   product_id           1072226 non-null  int64
#  8   cat0                 1072226 non-null  int64
#  9   cat1                 1072226 non-null  int64
#  10  cat2                 1072226 non-null  int64
#  11  cat3                 1072226 non-null  int64
#  12  cat4                 1072226 non-null  int64
#  13  cat5                 1072226 non-null  int64
#  14  cat6                 1072226 non-null  int64
#  15  cat7                 1072226 non-null  int64
#  16  cat8                 1072226 non-null  int64
#  17  cat9                 1072226 non-null  int64
#  18  cat10                1072226 non-null  int64
#  19  cat11                1072226 non-null  int64
#  20  cat12                1072226 non-null  int64
#  21  num16                1072226 non-null  float64
#  22  num17                1072226 non-null  float64
#  23  num18                1072226 non-null  float64
#  24  num19                1072226 non-null  float64
#  25  num20                1072226 non-null  float64
#  26  num21                1072226 non-null  float64
#  27  num22                1072226 non-null  float64
#  28  num23                1072226 non-null  float64
#  29  num24                1072226 non-null  float64
#  30  num25                1072226 non-null  float64
#  31  num26                1072226 non-null  float64
#  32  num27                1072226 non-null  float64
#  33  num28                1072226 non-null  float64
#  34  num29                1072226 non-null  float64
#  35  num30                1072226 non-null  float64
#  36  num31                1072226 non-null  float64
#  37  num32                1072226 non-null  float64
#  38  num33                1072226 non-null  float64
#  39  num34                1072226 non-null  float64
#  40  num35                1072226 non-null  float64
#  41  num36                1072226 non-null  float64
#  42  num37                1072226 non-null  float64
#  43  num38                1072226 non-null  float64
#  44  num39                1072226 non-null  float64
#  45  num40                1072226 non-null  float64
#  46  num41                1072226 non-null  float64
#  47  num42                1072226 non-null  float64
#  48  num43                1072226 non-null  float64
#  49  num44                1072226 non-null  float64
#  50  num45                1072226 non-null  float64
#  51  num46                1072226 non-null  float64
#  52  num47                1072226 non-null  float64
#  53  num48                1072226 non-null  float64
#  54  num49                1072226 non-null  float64
#  55  num50                1072226 non-null  float64
# dtypes: float64(35), int64(21)
# memory usage: 458.1 MB

# %%
print("Unique user_id:", df['user_id'].nunique())
print("Unique product_id:", df['product_id'].nunique())
print("Unique impression_id:", df['impression_id'].nunique())
# Out:
# Unique user_id: 30361
# Unique product_id: 57355
# Unique impression_id: 224898

# %%
df.columns
# Out:
# Index(['click', 'protected_attribute', 'senior', 'displayrandom', 'rank',
#        'user_id', 'impression_id', 'product_id', 'cat0', 'cat1', 'cat2',
#        'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8', 'cat9', 'cat10',
#        'cat11', 'cat12', 'num16', 'num17', 'num18', 'num19', 'num20', 'num21',
#        'num22', 'num23', 'num24', 'num25', 'num26', 'num27', 'num28', 'num29',
#        'num30', 'num31', 'num32', 'num33', 'num34', 'num35', 'num36', 'num37',
#        'num38', 'num39', 'num40', 'num41', 'num42', 'num43', 'num44', 'num45',
#        'num46', 'num47', 'num48', 'num49', 'num50'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# click                  0
# protected_attribute    0
# senior                 0
# displayrandom          0
# rank                   0
# user_id                0
# impression_id          0
# product_id             0
# cat0                   0
# cat1                   0
# cat2                   0
# cat3                   0
# cat4                   0
# cat5                   0
# cat6                   0
# cat7                   0
# cat8                   0
# cat9                   0
# cat10                  0
# cat11                  0
# cat12                  0
# num16                  0
# num17                  0
# num18                  0
# num19                  0
# num20                  0
# num21                  0
# num22                  0
# num23                  0
# num24                  0
# num25                  0
# num26                  0
# num27                  0
# num28                  0
# num29                  0
# num30                  0
# num31                  0
# num32                  0
# num33                  0
# num34                  0
# num35                  0
# num36                  0
# num37                  0
# num38                  0
# num39                  0
# num40                  0
# num41                  0
# num42                  0
# num43                  0
# num44                  0
# num45                  0
# num46                  0
# num47                  0
# num48                  0
# num49                  0
# num50                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for column in df.columns:
    print(f"Summary statistics for {column}:\n", df[column].describe(), "\n")
# Out:
# Summary statistics for click:
#  count    1.072226e+06
# mean     6.984535e-03
# std      8.328120e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: click, dtype: float64
#
# Summary statistics for protected_attribute:
#  count    1072226.0
# mean           0.5
# std            0.5
# min            0.0
# 25%            0.0
# 50%            0.5
# 75%            1.0
# max            1.0
# Name: protected_attribute, dtype: float64
#
# Summary statistics for senior:
#  count    1.072226e+06
# mean     6.655864e-01
# std      4.717853e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: senior, dtype: float64
#
# Summary statistics for displayrandom:
#  count    1.072226e+06
# mean     9.873758e-02
# std      2.983095e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: displayrandom, dtype: float64
#
# Summary statistics for rank:
#  count    1.072226e+06
# mean     6.172810e+00
# std      4.752105e+00
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      5.000000e+00
# 75%      9.000000e+00
# max      4.000000e+01
# Name: rank, dtype: float64
#
# Summary statistics for user_id:
#  count    1.072226e+06
# mean     1.599122e+04
# std      9.186927e+03
# min      0.000000e+00
# 25%      8.013000e+03
# 50%      1.610000e+04
# 75%      2.407575e+04
# max      3.187900e+04
# Name: user_id, dtype: float64
#
# Summary statistics for impression_id:
#  count    1.072226e+06
# mean     1.319778e+05
# std      6.477362e+04
# min      0.000000e+00
# 25%      7.858000e+04
# 50%      1.301310e+05
# 75%      1.887210e+05
# max      2.463600e+05
# Name: impression_id, dtype: float64
#
# Summary statistics for product_id:
#  count    1.072226e+06
# mean     3.064587e+04
# std      1.772469e+04
# min      0.000000e+00
# 25%      1.484900e+04
# 50%      3.073700e+04
# 75%      4.574000e+04
# max      6.215300e+04
# Name: product_id, dtype: float64
#
# Summary statistics for cat0:
#  count    1.072226e+06
# mean     6.375651e+00
# std      2.168938e+00
# min      0.000000e+00
# 25%      6.000000e+00
# 50%      7.000000e+00
# 75%      8.000000e+00
# max      8.000000e+00
# Name: cat0, dtype: float64
#
# Summary statistics for cat1:
#  count    1.072226e+06
# mean     6.715985e+00
# std      1.772106e+00
# min      0.000000e+00
# 25%      6.000000e+00
# 50%      8.000000e+00
# 75%      8.000000e+00
# max      8.000000e+00
# Name: cat1, dtype: float64
#
# Summary statistics for cat2:
#  count    1.072226e+06
# mean     5.057068e+02
# std      2.899688e+02
# min      0.000000e+00
# 25%      2.370000e+02
# 50%      4.920000e+02
# 75%      7.430000e+02
# max      1.028000e+03
# Name: cat2, dtype: float64
#
# Summary statistics for cat3:
#  count    1.072226e+06
# mean     6.171353e+01
# std      2.655050e+01
# min      0.000000e+00
# 25%      3.900000e+01
# 50%      7.300000e+01
# 75%      7.600000e+01
# max      9.700000e+01
# Name: cat3, dtype: float64
#
# Summary statistics for cat4:
#  count    1.072226e+06
# mean     5.817343e+01
# std      3.127829e+01
# min      0.000000e+00
# 25%      3.700000e+01
# 50%      5.400000e+01
# 75%      8.200000e+01
# max      1.210000e+02
# Name: cat4, dtype: float64
#
# Summary statistics for cat5:
#  count    1.072226e+06
# mean     7.126865e+02
# std      4.862076e+02
# min      0.000000e+00
# 25%      3.340000e+02
# 50%      7.000000e+02
# 75%      1.243000e+03
# max      1.352000e+03
# Name: cat5, dtype: float64
#
# Summary statistics for cat6:
#  count    1.072226e+06
# mean     8.160788e+02
# std      9.929583e+02
# min      0.000000e+00
# 25%      9.200000e+01
# 50%      1.580000e+02
# 75%      2.335000e+03
# max      2.579000e+03
# Name: cat6, dtype: float64
#
# Summary statistics for cat7:
#  count    1.072226e+06
# mean     1.299028e+03
# std      1.166578e+03
# min      0.000000e+00
# 25%      2.230000e+02
# 50%      9.080000e+02
# 75%      2.879000e+03
# max      3.317000e+03
# Name: cat7, dtype: float64
#
# Summary statistics for cat8:
#  count    1.072226e+06
# mean     9.597273e+02
# std      7.037296e+02
# min      0.000000e+00
# 25%      2.770000e+02
# 50%      8.460000e+02
# 75%      1.579000e+03
# max      3.660000e+03
# Name: cat8, dtype: float64
#
# Summary statistics for cat9:
#  count    1.072226e+06
# mean     6.225137e+02
# std      5.621759e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      6.730000e+02
# 75%      9.380000e+02
# max      3.005000e+03
# Name: cat9, dtype: float64
#
# Summary statistics for cat10:
#  count    1.072226e+06
# mean     3.221183e+02
# std      4.295243e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.500000e+02
# max      2.422000e+03
# Name: cat10, dtype: float64
#
# Summary statistics for cat11:
#  count    1.072226e+06
# mean     1.044305e+02
# std      2.174361e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.493000e+03
# Name: cat11, dtype: float64
#
# Summary statistics for cat12:
#  count    1.072226e+06
# mean     3.529761e+01
# std      1.095093e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.630000e+02
# Name: cat12, dtype: float64
#
# Summary statistics for num16:
#  count    1.072226e+06
# mean    -3.102335e-03
# std      9.422842e-01
# min     -1.078760e-01
# 25%     -1.078760e-01
# 50%     -1.078760e-01
# 75%     -1.078760e-01
# max      2.138099e+02
# Name: num16, dtype: float64
#
# Summary statistics for num17:
#  count    1.072226e+06
# mean    -3.911768e-03
# std      9.906989e-01
# min     -1.887426e-01
# 25%     -1.887426e-01
# 50%     -1.887426e-01
# 75%     -1.887426e-01
# max      3.513568e+01
# Name: num17, dtype: float64
#
# Summary statistics for num18:
#  count    1.072226e+06
# mean    -5.498826e-03
# std      1.050485e+00
# min     -1.341959e-01
# 25%     -1.341959e-01
# 50%     -1.341959e-01
# 75%     -1.341959e-01
# max      1.027169e+02
# Name: num18, dtype: float64
#
# Summary statistics for num19:
#  count    1.072226e+06
# mean    -8.453935e-03
# std      9.962367e-01
# min     -4.940338e-01
# 25%     -4.940338e-01
# 50%     -4.940338e-01
# 75%      1.026539e-02
# max      1.854943e+01
# Name: num19, dtype: float64
#
# Summary statistics for num20:
#  count    1.072226e+06
# mean    -2.498303e-02
# std      9.801861e-01
# min     -6.724055e-01
# 25%     -6.724055e-01
# 50%     -5.132421e-01
# 75%      2.780982e-01
# max      1.247731e+01
# Name: num20, dtype: float64
#
# Summary statistics for num21:
#  count    1.072226e+06
# mean    -3.367444e-02
# std      9.673168e-01
# min     -6.331214e-01
# 25%     -6.331214e-01
# 50%     -4.933852e-01
# 75%      1.434290e-01
# max      6.485426e+00
# Name: num21, dtype: float64
#
# Summary statistics for num22:
#  count    1.072226e+06
# mean    -1.704947e-02
# std      9.874333e-01
# min     -4.449792e-01
# 25%     -4.449792e-01
# 50%     -3.722606e-01
# 75%     -8.667842e-03
# max      3.673238e+01
# Name: num22, dtype: float64
#
# Summary statistics for num23:
#  count    1.072226e+06
# mean     1.285262e-03
# std      1.022297e+00
# min     -5.959098e-01
# 25%     -5.550767e-01
# 50%     -3.509109e-01
# 75%      1.595034e-01
# max      2.311842e+01
# Name: num23, dtype: float64
#
# Summary statistics for num24:
#  count    1.072226e+06
# mean     9.000216e-04
# std      1.006104e+00
# min     -5.195463e-01
# 25%     -5.195463e-01
# 50%     -5.195463e-01
# 75%      3.713186e-01
# max      1.056677e+01
# Name: num24, dtype: float64
#
# Summary statistics for num25:
#  count    1.072226e+06
# mean    -1.298662e-02
# std      9.798874e-01
# min     -5.444777e-01
# 25%     -5.444777e-01
# 50%     -5.444777e-01
# 75%      3.562778e-01
# max      1.791991e+01
# Name: num25, dtype: float64
#
# Summary statistics for num26:
#  count    1.072226e+06
# mean     1.934790e-03
# std      1.011330e+00
# min     -3.329289e-01
# 25%     -3.329289e-01
# 50%     -3.329289e-01
# 75%     -1.338334e-01
# max      2.301298e+01
# Name: num26, dtype: float64
#
# Summary statistics for num27:
#  count    1.072226e+06
# mean     2.275090e-03
# std      9.992461e-01
# min     -2.958202e-01
# 25%     -2.958202e-01
# 50%     -2.958202e-01
# 75%     -2.736996e-02
# max      2.112569e+01
# Name: num27, dtype: float64
#
# Summary statistics for num28:
#  count    1.072226e+06
# mean    -8.491722e-04
# std      1.006386e+00
# min     -3.491854e-01
# 25%     -3.491854e-01
# 50%     -3.056412e-01
# 75%     -1.096922e-01
# max      1.902799e+01
# Name: num28, dtype: float64
#
# Summary statistics for num29:
#  count    1.072226e+06
# mean    -9.272885e-03
# std      9.902307e-01
# min     -6.540597e-01
# 25%     -6.540597e-01
# 50%     -4.589430e-01
# 75%      2.239656e-01
# max      9.166491e+00
# Name: num29, dtype: float64
#
# Summary statistics for num30:
#  count    1.072226e+06
# mean     1.053439e-03
# std      1.019231e+00
# min     -7.658330e-01
# 25%     -6.106171e-01
# 50%     -3.031918e-01
# 75%      2.369122e-01
# max      1.993778e+01
# Name: num30, dtype: float64
# Summary statistics for num31:
#  count    1.072226e+06
# mean    -4.419865e-03
# std      1.029910e+00
# min     -4.579574e-01
# 25%     -4.426329e-01
# 50%     -3.123740e-01
# 75%      2.476655e-02
# max      9.437815e+01
# Name: num31, dtype: float64
#
# Summary statistics for num32:
#  count    1.072226e+06
# mean     4.841941e-03
# std      1.048641e+00
# min     -3.071417e-01
# 25%     -2.964027e-01
# 50%     -2.411738e-01
# 75%     -6.167996e-02
# max      5.676577e+01
# Name: num32, dtype: float64
#
# Summary statistics for num33:
#  count    1.072226e+06
# mean    -1.106058e-02
# std      9.951204e-01
# min     -3.876791e-01
# 25%     -3.876791e-01
# 50%     -3.711264e-01
# 75%     -5.993529e-02
# max      1.998209e+01
# Name: num33, dtype: float64
#
# Summary statistics for num34:
#  count    1.072226e+06
# mean     5.429876e-03
# std      1.052366e+00
# min     -3.134130e-01
# 25%     -3.001536e-01
# 50%     -2.426960e-01
# 75%     -5.853721e-02
# max      5.449373e+01
# Name: num34, dtype: float64
#
# Summary statistics for num35:
#  count    1.072226e+06
# mean     1.368673e-02
# std      1.012118e+00
# min     -1.026151e+00
# 25%     -1.026151e+00
# 50%      6.665724e-01
# 75%      6.665724e-01
# max      2.359296e+00
# Name: num35, dtype: float64
#
# Summary statistics for num36:
#  count    1.072226e+06
# mean    -1.104531e-02
# std      9.962517e-01
# min     -3.983859e-01
# 25%     -3.983859e-01
# 50%     -3.692808e-01
# 75%     -4.589080e-02
# max      1.949980e+01
# Name: num36, dtype: float64
#
# Summary statistics for num37:
#  count    1.072226e+06
# mean    -1.300854e-03
# std      9.829786e-01
# min     -3.156479e-01
# 25%     -3.156479e-01
# 50%     -3.156479e-01
# 75%     -2.337985e-02
# max      4.284189e+01
# Name: num37, dtype: float64
#
# Summary statistics for num38:
#  count    1.072226e+06
# mean    -1.166150e-02
# std      9.628703e-01
# min     -2.935008e-01
# 25%     -2.935008e-01
# 50%     -2.935008e-01
# 75%     -9.792399e-02
# max      3.129050e+01
# Name: num38, dtype: float64
#
# Summary statistics for num39:
#  count    1.072226e+06
# mean    -1.053418e-02
# std      9.679061e-01
# min     -3.140521e-01
# 25%     -3.140521e-01
# 50%     -3.140521e-01
# 75%     -1.350958e-01
# max      5.162175e+01
# Name: num39, dtype: float64
#
# Summary statistics for num40:
#  count    1.072226e+06
# mean     5.476312e-03
# std      1.051963e+00
# min     -2.922952e-01
# 25%     -2.833437e-01
# 50%     -2.356027e-01
# 75%     -7.000089e-02
# max      5.520817e+01
# Name: num40, dtype: float64
#
# Summary statistics for num41:
#  count    1.072226e+06
# mean    -2.016033e-03
# std      9.815474e-01
# min     -3.330331e-01
# 25%     -3.330331e-01
# 50%     -3.330331e-01
# 75%     -5.043495e-02
# max      4.036110e+01
# Name: num41, dtype: float64
#
# Summary statistics for num42:
#  count    1.072226e+06
# mean     3.005225e-05
# std      1.002444e+00
# min     -5.428010e-01
# 25%     -5.428010e-01
# 50%     -5.428010e-01
# 75%      9.253471e-01
# max      1.232409e+01
# Name: num42, dtype: float64
#
# Summary statistics for num43:
#  count    1.072226e+06
# mean    -1.030180e-02
# std      9.965941e-01
# min     -3.933585e-01
# 25%     -3.933585e-01
# 50%     -3.548728e-01
# 75%     -4.698716e-02
# max      1.978277e+01
# Name: num43, dtype: float64
#
# Summary statistics for num44:
#  count    1.072226e+06
# mean    -2.034811e-02
# std      9.896207e-01
# min     -9.877007e-01
# 25%     -8.371609e-01
# 50%     -3.830231e-01
# 75%      5.678776e-01
# max      1.429750e+01
# Name: num44, dtype: float64
#
# Summary statistics for num45:
#  count    1.072226e+06
# mean     5.085476e-03
# std      1.029254e+00
# min     -5.236676e-01
# 25%     -4.946516e-01
# 50%     -3.495715e-01
# 75%      8.566847e-02
# max      3.273832e+01
# Name: num45, dtype: float64
#
# Summary statistics for num46:
#  count    1.072226e+06
# mean     1.353991e-03
# std      1.018628e+00
# min     -7.789774e-01
# 25%     -6.201581e-01
# 50%     -3.031994e-01
# 75%      2.392567e-01
# max      2.052098e+01
# Name: num46, dtype: float64
#
# Summary statistics for num47:
#  count    1.072226e+06
# mean     1.537683e-03
# std      1.010206e+00
# min     -3.454804e-01
# 25%     -3.454804e-01
# 50%     -3.454804e-01
# 75%     -6.734302e-02
# max      2.233434e+01
# Name: num47, dtype: float64
#
# Summary statistics for num48:
#  count    1.072226e+06
# mean    -1.192159e-02
# std      9.816352e-01
# min     -5.771731e-01
# 25%     -5.771731e-01
# 50%     -5.771731e-01
# 75%      2.576640e-01
# max      1.857489e+01
# Name: num48, dtype: float64
#
# Summary statistics for num49:
#  count    1.072226e+06
# mean    -1.446661e-03
# std      9.991476e-01
# min     -2.643592e-01
# 25%     -2.643592e-01
# 50%     -2.643592e-01
# 75%     -2.643592e-01
# max      2.367227e+01
# Name: num49, dtype: float64
#
# Summary statistics for num50:
#  count    1.072226e+06
# mean    -2.136117e-02
# std      9.880157e-01
# min     -9.964498e-01
# 25%     -8.409591e-01
# 50%     -3.744871e-01
# 75%      5.584570e-01
# max      1.481177e+01
# Name: num50, dtype: float64

# %% [markdown]
# ### Plots

# %%
for col in ['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8', 'cat9', 'cat10', 'cat11', 'cat12']:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=90)
    plt.show()

# %%
numerical_features = [f'num{i}' for i in range(16, 51)]

for i in range(0, len(numerical_features), 5):
    cols = numerical_features[i:i+5]
    
    df[cols].hist(bins=20, figsize=(16, 10))
    plt.suptitle(f"Distribution of Numerical User Features: {cols}")
    plt.show()

# %%
sns.countplot(data=df, x='protected_attribute')
plt.title("Distribution of Protected Attribute (Gender Proxy)")
plt.show()

# %%
sns.countplot(data=df, x='senior')
plt.title("Distribution of Seniority Levels")
plt.show()

# %%
sns.countplot(data=df, x='click')
plt.title("Distribution of Clicks")
plt.show()

# %%
sns.histplot(data=df, x='rank', bins=20)
plt.title("Distribution of Product Ranks on Display")
plt.show()

# %%
sns.histplot(data=df, x='rank', bins=20, stat='count')
plt.title("Distribution of Product Ranks on Display")

# Add text annotations for each bar
for p in plt.gca().patches:
    height = p.get_height()
    if height > 0:  # Only label bars with height
        plt.text(p.get_x() + p.get_width() / 2, height, int(height), 
                 ha="center", va="bottom", fontsize=10, rotation=90)

plt.show()

# %%
sns.countplot(data=df, x='displayrandom')
plt.title("Distribution of Display Randomization")
plt.show()

# %% [markdown]
# ### Displayrandom
#
# #### Conclusions :
# - when an ad is displayed randomly, more than 50% of times it is displayed at a rank <=5

# %%
plt.figure(figsize=(12, 4))
sns.countplot(data=df[df['displayrandom']==1], x='rank')
plt.title("Ranks prefered during random display")

plt.show()

# %%
df[df['displayrandom']==1].describe()
# Out:
#                click  protected_attribute         senior  displayrandom
# count  105869.000000        105869.000000  105869.000000       105869.0  \
# mean        0.007235             0.499051       0.667211            1.0
# std         0.084753             0.500001       0.471214            0.0
# min         0.000000             0.000000       0.000000            1.0
# 25%         0.000000             0.000000       0.000000            1.0
# 50%         0.000000             0.000000       1.000000            1.0
# 75%         0.000000             1.000000       1.000000            1.0
# max         1.000000             1.000000       1.000000            1.0
#
#                 rank        user_id  impression_id     product_id
# count  105869.000000  105869.000000  105869.000000  105869.000000  \
# mean        6.147399   16041.632168  132246.649756   30639.683297
# std         4.628610    9185.051293   64313.748310   17753.950660
# min         1.000000       4.000000      87.000000       0.000000
# 25%         2.000000    8176.000000   78696.000000   14828.000000
# 50%         5.000000   16185.000000  129827.000000   30737.000000
# 75%         9.000000   24177.000000  189458.000000   45780.000000
# max        36.000000   31876.000000  246345.000000   62150.000000
#
#                 cat0           cat1  ...          num41          num42
# count  105869.000000  105869.000000  ...  105869.000000  105869.000000  \
# mean        6.374878       6.730932  ...       0.015450       0.022428
# std         2.177162       1.758853  ...       0.984787       1.026893
# min         0.000000       0.000000  ...      -0.333033      -0.542801
# 25%         6.000000       6.000000  ...      -0.333033      -0.542801
# 50%         7.000000       8.000000  ...      -0.333033      -0.542801
# 75%         8.000000       8.000000  ...      -0.050435       0.925347
# max         8.000000       8.000000  ...      33.296143      12.324090
#
#                num43          num44          num45          num46
# count  105869.000000  105869.000000  105869.000000  105869.000000  \
# mean       -0.008090      -0.007530       0.013818       0.008412
# std         1.028055       0.989270       1.060879       1.025412
# min        -0.393358      -0.987701      -0.523668      -0.778977
# 25%        -0.393358      -0.832324      -0.494652      -0.613185
# 50%        -0.354873      -0.335361      -0.349572      -0.303199
# 75%        -0.046987       0.592988       0.085668       0.237201
# max        18.381249       6.988833      27.111731      16.224220
#
#                num47          num48          num49          num50
# count  105869.000000  105869.000000  105869.000000  105869.000000
# mean        0.008876       0.000496      -0.011182      -0.011949
# std         1.008558       0.987954       0.970251       0.985006
# min        -0.345480      -0.577173      -0.264359      -0.996450
# 25%        -0.345480      -0.577173      -0.264359      -0.789129
# 50%        -0.345480      -0.577173      -0.264359      -0.374487
# 75%        -0.067343       0.257664      -0.264359       0.558457
# max        13.998769      10.275710      22.127972       7.244556
#
# [8 rows x 56 columns]

# %% [markdown]
# ### Feature vs Target relations

# %%
sns.barplot(data=df, x='protected_attribute', y='click')
plt.title("Click Rate by Gender Proxy (Protected Attribute)")
plt.show()

# %%
sns.barplot(data=df, x='senior', y='click')
plt.title("Click Rate by Seniority Level")
plt.show()

# %%
sns.lineplot(data=df, x='rank', y='click')
plt.title("Click Rate by Rank Position")
plt.show()

# %%
sns.barplot(data=df, x='displayrandom', y='click')
plt.title("Click Rate by Display Randomization")
plt.show()

# %%
corr_matrix = df[numerical_features].corr().abs()
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
high_corr_features = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.9)]
print("Highly correlated features:", high_corr_features)
# Out:
# Highly correlated features: ['num34', 'num36', 'num39', 'num40', 'num41', 'num42', 'num43', 'num46', 'num47', 'num48', 'num50']

# %%
cat_features = ['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8', 'cat9', 'cat10', 'cat11', 'cat12']
cat_corr_matrix = df[cat_features].corr().abs()
upper_triangle_cat = cat_corr_matrix.where(np.triu(np.ones(cat_corr_matrix.shape), k=1).astype(bool))
high_corr_cat_features = [column for column in upper_triangle_cat.columns if any(upper_triangle_cat[column] > 0.5)]
print("Highly correlated categorical features:", high_corr_cat_features)
# Out:
# Highly correlated categorical features: ['cat1', 'cat11', 'cat12']

# %%
low_variance_features = [col for col in df.columns if df[col].var() < 0.1]
print("Low-variance features:", low_variance_features)
# Out:
# Low-variance features: ['click', 'displayrandom']

# %% [markdown]
# ### More Analysis

# %%
new_df=df.groupby(['rank','protected_attribute','senior','displayrandom','click']).size().reset_index().rename(columns={0:'click_counts'})

# %%
new_df.head(1)
# Out:
#    rank  protected_attribute  senior  displayrandom  click  click_counts
# 0     1                    0       0              0      0         28321

# %%
# Calculate click-through rate (CTR) by rank
rank_click_rate = new_df.groupby('rank')['click'].mean().reset_index()

# Plot click rate by rank
plt.figure(figsize=(10, 6))
sns.lineplot(data=rank_click_rate, x='rank', y='click')
plt.title("Click Rate by Product Rank on Display")
plt.xlabel("Rank on Display")
plt.ylabel("Click Rate")
plt.show()

# %%
pivot_data = new_df.groupby(['rank', 'protected_attribute', 'senior'])['click'].mean().unstack(['protected_attribute', 'senior'])

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_data, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'Click Rate'})
plt.title("Click Rate by Rank, Protected Attribute (Gender), and Seniority")
plt.xlabel("Protected Attribute, Seniority (e.g., 0, 1 means Female, Managerial)")
plt.ylabel("Rank on Display")
plt.show()

# %%
plt.figure(figsize=(14, 8))

sns.barplot(
    x='rank', 
    y='click_counts', 
    hue='protected_attribute',  
    data=new_df,                 
)

plt.title("Click Counts by Rank with Protected Attribute")
plt.xlabel("Rank")
plt.ylabel("Click Counts")

plt.legend(title='Protected Attribute', loc='upper right')

plt.show()

# %%
plt.figure(figsize=(14, 8))

sns.barplot(
    x='rank', 
    y='click_counts', 
    hue='senior',  
    data=new_df,                 
)

plt.title("Click Counts by Rank with seniority level")
plt.xlabel("Rank")
plt.ylabel("Click Counts")

plt.legend(title='Protected Attribute', loc='upper right')

plt.show()

# %%
plt.figure(figsize=(14, 8))

sns.barplot(
    x='rank', 
    y='click_counts', 
    hue='displayrandom',  
    data=new_df,                 
)

plt.title("Click Counts by Rank with display random")
plt.xlabel("Rank")
plt.ylabel("Click Counts")

plt.legend(title='Protected Attribute', loc='upper right')

plt.show()

# %%
clicked_df = df[df['click'] == 1]
non_clicked_df = df[df['click'] == 0]

plt.figure(figsize=(14, 6))
sns.histplot(clicked_df['rank'], color='blue', kde=True, label='Clicked', bins=10)
sns.histplot(non_clicked_df['rank'], color='red', kde=True, label='Not Clicked', bins=10)
plt.yscale('log')
plt.title("Rank Distribution for Clicked vs. Non-Clicked Impressions (Log Scale)")
plt.xlabel("Rank")
plt.ylabel("Frequency (Log Scale)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.histplot(clicked_df['rank'], color='blue', kde=True, label='Clicked', bins=10, stat="density")
sns.histplot(non_clicked_df['rank'], color='red', kde=True, label='Not Clicked', bins=10, stat="density")
plt.title("Normalized Rank Distribution for Clicked vs. Non-Clicked Impressions")
plt.xlabel("Rank")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x='protected_attribute', hue='senior', data=clicked_df, palette='coolwarm')
plt.title("Protected Attribute and Seniority in Clicked Impressions")
plt.xlabel("Protected Attribute")
plt.ylabel("Count of Clicked Impressions")
plt.legend(title="Seniority")
plt.show()

# %%
clicked = 
non_clicked = 
corr_clicked = clicked_df.corr()
corr_non_clicked = non_clicked_df.corr()

plt.figure(figsize=(14, 6))
sns.heatmap(corr_clicked, cmap='YlGnBu', annot=False, cbar=True)
plt.title("Correlation Matrix for Clicked Impressions")
plt.show()

plt.figure(figsize=(14, 6))
sns.heatmap(corr_non_clicked, cmap='YlOrRd', annot=False, cbar=True)
plt.title("Correlation Matrix for Non-Clicked Impressions")
plt.show()
